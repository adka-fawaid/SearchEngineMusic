# %% [markdown]
# # **PreParation Data Scraping**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **connect gdrive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Memanggil Dataset**

# %%
data = pd.read_csv('/content/drive/MyDrive/Semester5/STKI/ProjectUAS/SearchEngine/static/Dataset/laguindo.csv', delimiter=';')

# %% [markdown]
# **menampilkan data teratas**

# %%
data.head()
# Out:
#          judul_lagu       nama_artis         playlist_name  \
# 0           Rangkum       Polka Wars  Indie Rock Indonesia
# 1  Laki-Laki Pemalu  Efek Rumah Kaca  Indie Rock Indonesia
# 2         Masa-Masa        The Adams  Indie Rock Indonesia
# 3       Another Day        The SIGIT  Indie Rock Indonesia
# 4             Barat        Barasuara  Indie Rock Indonesia
#
#                       url                                         genre_lagu  \
# 0  4j9AWlGmYrQwjxvmObIzXm                               ['indonesian indie']
# 1  5WUdbehFIiTDyw1vFCljNz  ['indonesian alternative rock', 'indonesian in...
# 2  3da9tjhBqR14I04nHHGnje  ['indonesian alternative rock', 'indonesian in...
# 3  06CTBs4mTFwJzlrmAvU6d0  ['indonesian alternative rock', 'indonesian in...
# 4  52E1hEuxwAfJIUGOpYmwyV      ['indonesian indie', 'indonesian indie rock']
#
#                                               lyrics
# 0  Tersingkap bila Menatap cah'ya Di dalam bahaya...
# 1  Senja akan segera berlalu Seorang lelaki melin...
# 2  Kau selalu ada Untuk tertawa Tak pernah lupa D...
# 3  These things are beautiful Don't think they're...
# 4  Kami menuju barat Maut kian melambat Merah mel...

# %% [markdown]
# **menampilkan data paling bawah**

# %%
data.tail()
# Out:
#                judul_lagu          nama_artis           playlist_name  \
# 1422               Jalang     Efek Rumah Kaca  2000s Indonesian Indie
# 1423              Jikalau           The Adams  2000s Indonesian Indie
# 1424  Rocket Ship Goes By  Goodnight Electric  2000s Indonesian Indie
# 1425      Hidup Itu Indah                Naif  2000s Indonesian Indie
# 1426       Jamaica's Away             Souljah  2000s Indonesian Indie
#
#                          url  \
# 1422  6qcvBgioxWYn1vPXJlKou3
# 1423  36YxF0N7WM32JmtXwEBM39
# 1424  55kXXCCGYokhnIB1hm5qYB
# 1425  3XJDtP8dGjZ6RtNQ5AIWhv
# 1426  2GEEAmaNtdLaMlqdMj0Dl1
#
#                                              genre_lagu  \
# 1422  ['indonesian alternative rock', 'indonesian in...
# 1423  ['indonesian alternative rock', 'indonesian in...
# 1424                               ['indonesian indie']
# 1425  ['indonesian indie', 'indonesian pop', 'indone...
# 1426  ['indonesian pop rock', 'indonesian reggae', '...
#
#                                                  lyrics
# 1422  Siapa yang berani bernyanyi Nanti akan dikebir...
# 1423  Jikalau telah datang Waktu yang dinanti Kupast...
# 1424  I remember when you said We have come from out...
# 1425  Saat kau buka mata kita dilahirkan untuk sama ...
# 1426  Jamaica's away Away from the land that I am li...

# %% [markdown]
# **melihat informasi data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1427 entries, 0 to 1426
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   judul_lagu     1427 non-null   object
#  1   nama_artis     1427 non-null   object
#  2   playlist_name  1427 non-null   object
#  3   url            1427 non-null   object
#  4   genre_lagu     1427 non-null   object
#  5   lyrics         1427 non-null   object
# dtypes: object(6)
# memory usage: 67.0+ KB

# %% [markdown]
# **merename nama kolom**

# %%
data.rename(columns={"lyrics": "Lirik_lagu"}, inplace=True)
data.rename(columns={"url": "uri"}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1427 entries, 0 to 1426
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   judul_lagu     1427 non-null   object
#  1   nama_artis     1427 non-null   object
#  2   playlist_name  1427 non-null   object
#  3   uri            1427 non-null   object
#  4   genre_lagu     1427 non-null   object
#  5   Lirik_lagu     1427 non-null   object
# dtypes: object(6)
# memory usage: 67.0+ KB

# %%
data.describe()
# Out:
#                                           judul_lagu nama_artis  \
# count                                           1427       1427
# unique                                          1092        303
# top     Sampai Jadi Debu (Menampilkan Gardika Gigih)  Iwan Fals
# freq                                               5        107
#
#                       playlist_name                     uri  \
# count                          1427                    1427
# unique                           26                    1172
# top     Iwan Fals, Dewa 19, & Slank  0ROj512WvJ1eqeELd7MEdJ
# freq                             99                       5
#
#                          genre_lagu  \
# count                          1427
# unique                          154
# top     ['classic indonesian rock']
# freq                            107
#
#                                                Lirik_lagu
# count                                                1427
# unique                                               1099
# top     Badai Tuan telah berlalu Salahkah ku menuntut ...
# freq                                                    5

# %% [markdown]
# **memilih kolom yang mau diperlukan**

# %%
data = data[['uri', 'nama_artis', 'judul_lagu', 'genre_lagu', 'Lirik_lagu']]
data
# Out:
#                          uri          nama_artis           judul_lagu  \
# 0     4j9AWlGmYrQwjxvmObIzXm          Polka Wars              Rangkum
# 1     5WUdbehFIiTDyw1vFCljNz     Efek Rumah Kaca     Laki-Laki Pemalu
# 2     3da9tjhBqR14I04nHHGnje           The Adams            Masa-Masa
# 3     06CTBs4mTFwJzlrmAvU6d0           The SIGIT          Another Day
# 4     52E1hEuxwAfJIUGOpYmwyV           Barasuara                Barat
# ...                      ...                 ...                  ...
# 1422  6qcvBgioxWYn1vPXJlKou3     Efek Rumah Kaca               Jalang
# 1423  36YxF0N7WM32JmtXwEBM39           The Adams              Jikalau
# 1424  55kXXCCGYokhnIB1hm5qYB  Goodnight Electric  Rocket Ship Goes By
# 1425  3XJDtP8dGjZ6RtNQ5AIWhv                Naif      Hidup Itu Indah
# 1426  2GEEAmaNtdLaMlqdMj0Dl1             Souljah       Jamaica's Away
#
#                                              genre_lagu  \
# 0                                  ['indonesian indie']
# 1     ['indonesian alternative rock', 'indonesian in...
# 2     ['indonesian alternative rock', 'indonesian in...
# 3     ['indonesian alternative rock', 'indonesian in...
# 4         ['indonesian indie', 'indonesian indie rock']
# ...                                                 ...
# 1422  ['indonesian alternative rock', 'indonesian in...
# 1423  ['indonesian alternative rock', 'indonesian in...
# 1424                               ['indonesian indie']
# 1425  ['indonesian indie', 'indonesian pop', 'indone...
# 1426  ['indonesian pop rock', 'indonesian reggae', '...
#
#                                              Lirik_lagu
# 0     Tersingkap bila Menatap cah'ya Di dalam bahaya...
# 1     Senja akan segera berlalu Seorang lelaki melin...
# 2     Kau selalu ada Untuk tertawa Tak pernah lupa D...
# 3     These things are beautiful Don't think they're...
# 4     Kami menuju barat Maut kian melambat Merah mel...
# ...                                                 ...
# 1422  Siapa yang berani bernyanyi Nanti akan dikebir...
# 1423  Jikalau telah datang Waktu yang dinanti Kupast...
# 1424  I remember when you said We have come from out...
# 1425  Saat kau buka mata kita dilahirkan untuk sama ...
# 1426  Jamaica's away Away from the land that I am li...
#
# [1427 rows x 5 columns]

# %% [markdown]
# **menghapus karakter pemisah baris**

# %%
data['Lirik_lagu'] = data['Lirik_lagu'].replace(r'\r\n',  '', regex=True)
# Out:
# <ipython-input-13-c9b2bc83b406>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Lirik_lagu'] = data['Lirik_lagu'].replace(r'\r\n',  '', regex=True)

# %% [markdown]
# **mencari data yang kosong**

# %%
data.isnull().sum()
# Out:
# uri           0
# nama_artis    0
# judul_lagu    0
# genre_lagu    0
# Lirik_lagu    0
# dtype: int64

# %% [markdown]
#  **mencari data duplikat pada kolom lirik**

# %%
data.duplicated(subset='Lirik_lagu').sum()
# Out:
# 328

# %% [markdown]
# **#menghapus lirik yang sama**

# %%
data.drop_duplicates(subset='Lirik_lagu', inplace=True)
# Out:
# <ipython-input-16-71d2ef97d256>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(subset='Lirik_lagu', inplace=True)

# %%
data.duplicated(subset='Lirik_lagu').sum()
# Out:
# 0

# %% [markdown]
# **menggabungkan kolom artis dan  judullagu**

# %%
data['artis_judulLagu'] = data['nama_artis'] + ' - ' + data['judul_lagu']
# Out:
# <ipython-input-18-6fd8c20caf9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['artis_judulLagu'] = data['nama_artis'] + ' - ' + data['judul_lagu']

# %%
data
# Out:
#                          uri          nama_artis           judul_lagu  \
# 0     4j9AWlGmYrQwjxvmObIzXm          Polka Wars              Rangkum
# 1     5WUdbehFIiTDyw1vFCljNz     Efek Rumah Kaca     Laki-Laki Pemalu
# 2     3da9tjhBqR14I04nHHGnje           The Adams            Masa-Masa
# 3     06CTBs4mTFwJzlrmAvU6d0           The SIGIT          Another Day
# 4     52E1hEuxwAfJIUGOpYmwyV           Barasuara                Barat
# ...                      ...                 ...                  ...
# 1422  6qcvBgioxWYn1vPXJlKou3     Efek Rumah Kaca               Jalang
# 1423  36YxF0N7WM32JmtXwEBM39           The Adams              Jikalau
# 1424  55kXXCCGYokhnIB1hm5qYB  Goodnight Electric  Rocket Ship Goes By
# 1425  3XJDtP8dGjZ6RtNQ5AIWhv                Naif      Hidup Itu Indah
# 1426  2GEEAmaNtdLaMlqdMj0Dl1             Souljah       Jamaica's Away
#
#                                              genre_lagu  \
# 0                                  ['indonesian indie']
# 1     ['indonesian alternative rock', 'indonesian in...
# 2     ['indonesian alternative rock', 'indonesian in...
# 3     ['indonesian alternative rock', 'indonesian in...
# 4         ['indonesian indie', 'indonesian indie rock']
# ...                                                 ...
# 1422  ['indonesian alternative rock', 'indonesian in...
# 1423  ['indonesian alternative rock', 'indonesian in...
# 1424                               ['indonesian indie']
# 1425  ['indonesian indie', 'indonesian pop', 'indone...
# 1426  ['indonesian pop rock', 'indonesian reggae', '...
#
#                                              Lirik_lagu  \
# 0     Tersingkap bila Menatap cah'ya Di dalam bahaya...
# 1     Senja akan segera berlalu Seorang lelaki melin...
# 2     Kau selalu ada Untuk tertawa Tak pernah lupa D...
# 3     These things are beautiful Don't think they're...
# 4     Kami menuju barat Maut kian melambat Merah mel...
# ...                                                 ...
# 1422  Siapa yang berani bernyanyi Nanti akan dikebir...
# 1423  Jikalau telah datang Waktu yang dinanti Kupast...
# 1424  I remember when you said We have come from out...
# 1425  Saat kau buka mata kita dilahirkan untuk sama ...
# 1426  Jamaica's away Away from the land that I am li...
#
#                                artis_judulLagu
# 0                         Polka Wars - Rangkum
# 1           Efek Rumah Kaca - Laki-Laki Pemalu
# 2                        The Adams - Masa-Masa
# 3                      The SIGIT - Another Day
# 4                            Barasuara - Barat
# ...                                        ...
# 1422                  Efek Rumah Kaca - Jalang
# 1423                       The Adams - Jikalau
# 1424  Goodnight Electric - Rocket Ship Goes By
# 1425                    Naif - Hidup Itu Indah
# 1426                  Souljah - Jamaica's Away
#
# [1099 rows x 6 columns]

# %% [markdown]
# **mengonversi nilai dalam kolom genre_lagu  menjadi list Python asli**

# %%
import ast

def convert(obj):
  L = []
  for i in ast.literal_eval(obj):
    L.append(i)
  return L

data['genre_lagu'] = data['genre_lagu'].apply(convert)

# %% [markdown]
# **menghapus spasi**

# %%
data['genre_lagu'] = data['genre_lagu'].apply(lambda x:[i.replace(" ", "") for i in x])
data['nama_artis'] = data['nama_artis'].apply(lambda x:x.replace(" ", ""))

data.head()
# Out:
#                       uri     nama_artis        judul_lagu  \
# 0  4j9AWlGmYrQwjxvmObIzXm      PolkaWars           Rangkum
# 1  5WUdbehFIiTDyw1vFCljNz  EfekRumahKaca  Laki-Laki Pemalu
# 2  3da9tjhBqR14I04nHHGnje       TheAdams         Masa-Masa
# 3  06CTBs4mTFwJzlrmAvU6d0       TheSIGIT       Another Day
# 4  52E1hEuxwAfJIUGOpYmwyV      Barasuara             Barat
#
#                                           genre_lagu  \
# 0                                  [indonesianindie]
# 1  [indonesianalternativerock, indonesianindie, i...
# 2  [indonesianalternativerock, indonesianindie, i...
# 3  [indonesianalternativerock, indonesianindie, i...
# 4             [indonesianindie, indonesianindierock]
#
#                                           Lirik_lagu  \
# 0  Tersingkap bila Menatap cah'ya Di dalam bahaya...
# 1  Senja akan segera berlalu Seorang lelaki melin...
# 2  Kau selalu ada Untuk tertawa Tak pernah lupa D...
# 3  These things are beautiful Don't think they're...
# 4  Kami menuju barat Maut kian melambat Merah mel...
#
#                       artis_judulLagu
# 0                Polka Wars - Rangkum
# 1  Efek Rumah Kaca - Laki-Laki Pemalu
# 2               The Adams - Masa-Masa
# 3             The SIGIT - Another Day
# 4                   Barasuara - Barat

# %% [markdown]
# **memisahkan per kata**

# %%
data['Lirik_lagu'] = data['Lirik_lagu'].apply(lambda x:x.split())
data['nama_artis'] = data['nama_artis'].apply(lambda x:x.split())
data.head()
# Out:
#                       uri       nama_artis        judul_lagu  \
# 0  4j9AWlGmYrQwjxvmObIzXm      [PolkaWars]           Rangkum
# 1  5WUdbehFIiTDyw1vFCljNz  [EfekRumahKaca]  Laki-Laki Pemalu
# 2  3da9tjhBqR14I04nHHGnje       [TheAdams]         Masa-Masa
# 3  06CTBs4mTFwJzlrmAvU6d0       [TheSIGIT]       Another Day
# 4  52E1hEuxwAfJIUGOpYmwyV      [Barasuara]             Barat
#
#                                           genre_lagu  \
# 0                                  [indonesianindie]
# 1  [indonesianalternativerock, indonesianindie, i...
# 2  [indonesianalternativerock, indonesianindie, i...
# 3  [indonesianalternativerock, indonesianindie, i...
# 4             [indonesianindie, indonesianindierock]
#
#                                           Lirik_lagu  \
# 0  [Tersingkap, bila, Menatap, cah'ya, Di, dalam,...
# 1  [Senja, akan, segera, berlalu, Seorang, lelaki...
# 2  [Kau, selalu, ada, Untuk, tertawa, Tak, pernah...
# 3  [These, things, are, beautiful, Don't, think, ...
# 4  [Kami, menuju, barat, Maut, kian, melambat, Me...
#
#                       artis_judulLagu
# 0                Polka Wars - Rangkum
# 1  Efek Rumah Kaca - Laki-Laki Pemalu
# 2               The Adams - Masa-Masa
# 3             The SIGIT - Another Day
# 4                   Barasuara - Barat

# %% [markdown]
# **menggabungkan kolom lirik lagu, nama artis dan genre**

# %%
data['Label'] = data['Lirik_lagu'] + data['nama_artis'] + data['genre_lagu']
data.head(10)
# Out:
#                       uri                nama_artis  \
# 0  4j9AWlGmYrQwjxvmObIzXm               [PolkaWars]
# 1  5WUdbehFIiTDyw1vFCljNz           [EfekRumahKaca]
# 2  3da9tjhBqR14I04nHHGnje                [TheAdams]
# 3  06CTBs4mTFwJzlrmAvU6d0                [TheSIGIT]
# 4  52E1hEuxwAfJIUGOpYmwyV               [Barasuara]
# 5  12ljrhiUlBUW8xi8k7sWid                  [Mooner]
# 6  3V0yduUwPTwpNTDskCSPh2  [KelompokPenerbangRoket]
# 7  3zMJiWwtg4LIXXSZ53uKAM  [KelompokPenerbangRoket]
# 8  15cki3Uuq7qYnEmilHyIHs               [PolkaWars]
# 9  0H3I8PJh0mbJ5tSRleYywg           [EfekRumahKaca]
#
#                        judul_lagu  \
# 0                         Rangkum
# 1                Laki-Laki Pemalu
# 2                       Masa-Masa
# 3                     Another Day
# 4                           Barat
# 5                      Menenggala
# 6                       Roda Gila
# 7                       Mati Muda
# 8                     Fatamorgana
# 9  Kau dan Aku Menuju Ruang Hampa
#
#                                           genre_lagu  \
# 0                                  [indonesianindie]
# 1  [indonesianalternativerock, indonesianindie, i...
# 2  [indonesianalternativerock, indonesianindie, i...
# 3  [indonesianalternativerock, indonesianindie, i...
# 4             [indonesianindie, indonesianindierock]
# 5  [indonesianindie, indonesianindierock, indones...
# 6  [indonesianindie, indonesianindierock, indones...
# 7  [indonesianindie, indonesianindierock, indones...
# 8                                  [indonesianindie]
# 9  [indonesianalternativerock, indonesianindie, i...
#
#                                           Lirik_lagu  \
# 0  [Tersingkap, bila, Menatap, cah'ya, Di, dalam,...
# 1  [Senja, akan, segera, berlalu, Seorang, lelaki...
# 2  [Kau, selalu, ada, Untuk, tertawa, Tak, pernah...
# 3  [These, things, are, beautiful, Don't, think, ...
# 4  [Kami, menuju, barat, Maut, kian, melambat, Me...
# 5  [Lalalala,, menenggala, Demi, gala,, demi, hal...
# 6  [Kehidupan, Di, dunia, Banyak, cara, terlupa, ...
# 7  [Berseragam, berlaga, jagoan, Mau, jadi, apa?,...
# 8  [Terbelah, jalan,, hampa, tujuan, Berdagang, a...
# 9  [Akan, ke, manakah, aku, dibawanya?, Hingga, s...
#
#                                     artis_judulLagu  \
# 0                              Polka Wars - Rangkum
# 1                Efek Rumah Kaca - Laki-Laki Pemalu
# 2                             The Adams - Masa-Masa
# 3                           The SIGIT - Another Day
# 4                                 Barasuara - Barat
# 5                               Mooner - Menenggala
# 6              Kelompok Penerbang Roket - Roda Gila
# 7              Kelompok Penerbang Roket - Mati Muda
# 8                          Polka Wars - Fatamorgana
# 9  Efek Rumah Kaca - Kau dan Aku Menuju Ruang Hampa
#
#                                                Label
# 0  [Tersingkap, bila, Menatap, cah'ya, Di, dalam,...
# 1  [Senja, akan, segera, berlalu, Seorang, lelaki...
# 2  [Kau, selalu, ada, Untuk, tertawa, Tak, pernah...
# 3  [These, things, are, beautiful, Don't, think, ...
# 4  [Kami, menuju, barat, Maut, kian, melambat, Me...
# 5  [Lalalala,, menenggala, Demi, gala,, demi, hal...
# 6  [Kehidupan, Di, dunia, Banyak, cara, terlupa, ...
# 7  [Berseragam, berlaga, jagoan, Mau, jadi, apa?,...
# 8  [Terbelah, jalan,, hampa, tujuan, Berdagang, a...
# 9  [Akan, ke, manakah, aku, dibawanya?, Hingga, s...

# %% [markdown]
# **membuat variable data baru untuk memuat data baru yang diperlukan**

# %%
new_data_indo = data[['uri', 'artis_judulLagu', 'Label']]

# %% [markdown]
# **menggabungkan elemen-elemen dalam list pada kolom Label menjadi satu string**
#
# ---

# %%
new_data_indo['Label'] = new_data_indo['Label'].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-25-6749ba87ec78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data_indo['Label'] = new_data_indo['Label'].apply(lambda x:" ".join(x))

# %%
new_data_indo['Label'][0]
# Out:
# "Tersingkap bila Menatap cah'ya Di dalam bahaya terjamah Bersila diam Menuju terang Deras bulir meresapi lara Malam musim semi Raja alam rasa Berakhir di sana Kata rangkumkan udara ... PolkaWars indonesianindie"

# %% [markdown]
# **melakukan stemming pada teks, yaitu mengubah setiap kata dalam teks ke bentuk dasar (root word) menggunakan algoritma Porter Stemmer dari NLTK.**

# %%
import nltk
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()
def stem(text):
  y = []

  for i in text.split():
    y.append(ps.stem(i))

  return " ".join(y)

# %% [markdown]
# **proses stemming pada setiap teks dalam kolom Label di DataFrame new_data_indo, sehingga semua kata dalam teks diubah ke bentuk dasarnya**

# %%
new_data_indo['Label'] = new_data_indo['Label'].apply(stem)
# Out:
# <ipython-input-28-fb1ad977d6c9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data_indo['Label'] = new_data_indo['Label'].apply(stem)

# %%
new_data_indo['Label'][0]
# Out:
# "tersingkap bila menatap cah'ya di dalam bahaya terjamah bersila diam menuju terang dera bulir meresapi lara malam musim semi raja alam rasa berakhir di sana kata rangkumkan udara ... polkawar indonesianindi"

# %% [markdown]
# **mengubah semua teks dalam kolom Label di DataFrame new_data_indo menjadi huruf kecil (lowercase), sehingga lebih konsisten untuk analisis teks**

# %%
new_data_indo['Label'] = new_data_indo['Label'].apply(lambda x:x.lower())
# Out:
# <ipython-input-30-80ad31cd3a69>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data_indo['Label'] = new_data_indo['Label'].apply(lambda x:x.lower())

# %%
new_data_indo.head()
# Out:
#                       uri                     artis_judulLagu  \
# 0  4j9AWlGmYrQwjxvmObIzXm                Polka Wars - Rangkum
# 1  5WUdbehFIiTDyw1vFCljNz  Efek Rumah Kaca - Laki-Laki Pemalu
# 2  3da9tjhBqR14I04nHHGnje               The Adams - Masa-Masa
# 3  06CTBs4mTFwJzlrmAvU6d0             The SIGIT - Another Day
# 4  52E1hEuxwAfJIUGOpYmwyV                   Barasuara - Barat
#
#                                                Label
# 0  tersingkap bila menatap cah'ya di dalam bahaya...
# 1  senja akan segera berlalu seorang lelaki melin...
# 2  kau selalu ada untuk tertawa tak pernah lupa d...
# 3  these thing are beauti don't think they'r reac...
# 4  kami menuju barat maut kian melambat merah mel...

# %% [markdown]
# **Simpan DataFrame ke file CSV**

# %%
new_data_indo.to_csv('laguindo_bersih.csv', index=False)
