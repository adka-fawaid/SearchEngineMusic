# %% [markdown]
# # **Menggabungkan Data Yang Sudah Dibersihkan**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# Baca dataset pertama
df1 = pd.read_csv('/content/drive/MyDrive/Semester5/STKI/ProjectUAS/SearchEngine/static/datagithub_bersih.csv')

# Baca dataset kedua
df2 = pd.read_csv('/content/drive/MyDrive/Semester5/STKI/ProjectUAS/SearchEngine/static/laguindo_bersih.csv')

# Gabungkan dataset secara vertikal (baris ditambahkan)
result = pd.concat([df1, df2], ignore_index=True)

# Simpan hasil penggabungan ke file baru
result.to_csv('Databaru.csv', index=False)

print("Dataset berhasil digabungkan!")
# Out:
# Dataset berhasil digabungkan!

# %% [markdown]
# **Memanggil dataset**

# %%
data = pd.read_csv('/content/drive/MyDrive/Semester5/STKI/ProjectUAS/SearchEngine/static/Databaru.csv')

# %%
data
# Out:
#                          uri                               artis_judulLagu  \
# 0     0UATU9OJxh4m3fwDljdGZn                    Evalyn - Creme de la creme
# 1     4JH1M62gVDNDhDAUiQB3Qv              Café Tacvba - La muerte chiquita
# 2     0h7Ld5CvgzaUN1zA3tdyPq                   Dawn Richard - we, diamonds
# 3     4S1bYWrLOC8smuy8kJzxKQ  Ricky Martin - Te Extraño, Te Olvido, Te Amo
# 4     758mQT4zzlvBhy9PvNePwC                 A Tribe Called Quest - Butter
# ...                      ...                                           ...
# 8201  6qcvBgioxWYn1vPXJlKou3                      Efek Rumah Kaca - Jalang
# 8202  36YxF0N7WM32JmtXwEBM39                           The Adams - Jikalau
# 8203  55kXXCCGYokhnIB1hm5qYB      Goodnight Electric - Rocket Ship Goes By
# 8204  3XJDtP8dGjZ6RtNQ5AIWhv                        Naif - Hidup Itu Indah
# 8205  2GEEAmaNtdLaMlqdMj0Dl1                      Souljah - Jamaica's Away
#
#                                                   Label
# ...
